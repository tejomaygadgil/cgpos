# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pickle 
import os
import logging

from hydra import initialize, compose
import pandas as pd

from cgpos.data.make_dataset import load_perseus

# %%
# Load hydra params
initialize("../conf", version_base=None)
config = compose(config_name='main')
# Init logger
logging.basicConfig(level=logging.DEBUG)

# %%
data = load_perseus(config)

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#         id         form       lemma     postag relation head  \
# 0        1   Θουκυδίδης  Θουκυδίδης  n-s---mn-      SBJ    3
# 1        2     Ἀθηναῖος    Ἀθηναῖος  n-s---mn-      ATR    1
# 2        3    ξυνέγραψε    συγγράφω  v3saia---     PRED    0
# 3        4          τὸν           ὁ  l-s---ma-      ATR    5
# 4        5      πόλεμον     πόλεμος  n-s---ma-   OBJ_AP   10
# ...     ..          ...         ...        ...      ...  ...
# 615667  66          διὰ         διά  r--------     AuxP   69
# 615668  67          τοῦ           ὁ  l-s---ng-      ATR   68
# 615669  68        πυρὸς         πῦρ  n-s---ng-      ADV   66
# 615670  69  ἐξαλλόμενον   ἐξάλλομαι  v-sppema-      ATR   61
# 615671  70            .           .  u--------     AuxK    0
#
#                                          document_id subdoc sentence_id  \
# 0       urn:cts:greekLit:tlg0003.tlg001.perseus-grc1  1.1.1           1
# 1       urn:cts:greekLit:tlg0003.tlg001.perseus-grc1  1.1.1           1
# 2       urn:cts:greekLit:tlg0003.tlg001.perseus-grc1  1.1.1           1
# 3       urn:cts:greekLit:tlg0003.tlg001.perseus-grc1  1.1.1           1
# 4       urn:cts:greekLit:tlg0003.tlg001.perseus-grc1  1.1.1           1
# ...                                              ...    ...         ...
# 615667  urn:cts:greekLit:tlg0007.tlg015.perseus-grc1   39.5         431
# 615668  urn:cts:greekLit:tlg0007.tlg015.perseus-grc1   39.5         431
# 615669  urn:cts:greekLit:tlg0007.tlg015.perseus-grc1   39.5         431
# 615670  urn:cts:greekLit:tlg0007.tlg015.perseus-grc1   39.5         431
# 615671  urn:cts:greekLit:tlg0007.tlg015.perseus-grc1   39.5         431
#
#        insertion_id artificial cite  ref   sg gloss
# 0               NaN        NaN  NaN  NaN  NaN   NaN
# 1               NaN        NaN  NaN  NaN  NaN   NaN
# 2               NaN        NaN  NaN  NaN  NaN   NaN
# 3               NaN        NaN  NaN  NaN  NaN   NaN
# 4               NaN        NaN  NaN  NaN  NaN   NaN
# ...             ...        ...  ...  ...  ...   ...
# 615667          NaN        NaN  NaN  NaN  NaN   NaN
# 615668          NaN        NaN  NaN  NaN  NaN   NaN
# 615669          NaN        NaN  NaN  NaN  NaN   NaN
# 615670          NaN        NaN  NaN  NaN  NaN   NaN
# 615671          NaN        NaN  NaN  NaN  NaN   NaN
#
# [615672 rows x 15 columns]
