# %% [markdown]
# # Goal: read in XML data from UD treebanks

# %%
import os
import xml.etree.ElementTree as ET

# %%
DATA_DIR = '../data/raw/'
folders = os.listdir(DATA_DIR)

# %%
folders
# Out:
# ['treebank_data-master', '.gitkeep', 'Greek-Dependency-Trees-master', 'zip']

# %%
# Let's start with Perseus
file_name = folders[0] + '/v2.0/Greek/TAGSETS.xml'
file_dir = os.path.join(DATA_DIR, file_name)

# Load XML
tree = ET.parse(file_dir)
root = tree.getroot()
node = root.find('plugins/sg/labels')

# Define function to print out XML tree
def print_children(root, level=10, ind=0):
    for child in root:
        tab = "  " * ind
        tag = child.tag
        long = child.find('long').text
        print(tab + f"{tag}: {long}")
        for element in child:
            if (element.tag == 'nested') and (level > 0):
                print_children(element, level-1, ind+1)

# %%
# Coarse labels
print_children(node, level=0)
# Out:
# adj: adjective
# art: article
# prn: pronoun
# adp: adposition
# noun: noun
# verb: verb
# adv: adverb
# nrl: numeral

# %%
# Finer labels
print_children(node, level=1)
# Out:
# adj: adjective
#   prp: adjective proper
#   sbs: substantive adjective
#   vrb__prp: verbal adjective proper
#   vrb__sbs: substantive verbal adjective
#   nna: none of the above
#   idk: I do not know
# art: article
# prn: pronoun
#   sbs: substantive pronoun
#   adj: adjective pronoun
#   nna: none of the above
#   idk: I do not know
# adp: adposition
# noun: noun
#   nmn: nominative
#   gnt: genitive
#   dtv: dative
#   acc: accusative
#   vct: vocative
#   nna: none of the above
#   idk: I do not know
# verb: verb
#   fnt: finite verb
#   prt: participle
#   inf: infinitive
#   nna: none of the above
#   idk: I do not know
# adv: adverb
#   tmp: time
#   plc: place
#   src: source
#   cau: cause
#   cns: result
#   mnn: manner
#   msr: measure
#   ins__mns: instrument or means
#   fnl: purpose
#   cnc: concession
#   ngt: negation
#   prt: particle
#   nna: none of the above
#   idk: I do not know
# nrl: numeral
#   crd: cardinal
#   ord: ordinal
#   adv: adverb
#   nna: none of the above
#   idk: I do not know

# %%
# Even finer labels
print_children(node, level=3)
# Out:
# adj: adjective
#   prp: adjective proper
#   sbs: substantive adjective
#     nmn: nominative
#       dpd: dependent
#       ind: independent
#       nna: none of the above
#       idk: I do not know
#     gnt: genitive
#       dpd: dependent
#       ind: independent
#       nna: none of the above
#       idk: I do not know
#     dtv: dative
#       dpd: dependent
#       nna: none of the above
#       idk: I do not know
#     acc: accusative
#       dpd: dependent
#       ind: independent
#       nna: none of the above
#       idk: I do not know
#     vct: vocative
#     nna: none of the above
#     idk: I do not know
#   vrb__prp: verbal adjective proper
#   vrb__sbs: substantive verbal adjective
#     nmn: nominative
#       dpd: dependent
#       ind: independent
#       nna: none of the above
#       idk: I do not know
#     gnt: genitive
#       dpd: dependent
#       ind: independent
#       nna: none of the above
#       idk: I do not know
#     dtv: dative
#       dpd: dependent
#       nna: none of the above
#       idk: I do not know
#     acc: accusative
#       dpd: dependent
#       ind: independent
#       nna: none of the above
#       idk: I do not know
#     vct: vocative
#     nna: none of the above
#     idk: I do not know
#   nna: none of the above
#   idk: I do not know
# art: article
# prn: pronoun
#   sbs: substantive pronoun
#     nmn: nominative
#       dpd: dependent
#       ind: independent
#       nna: none of the above
#       idk: I do not know
#     gnt: genitive
#       dpd: dependent
#       ind: independent
#       nna: none of the above
#       idk: I do not know
#     dtv: dative
#       dpd: dependent
#       nna: none of the above
#       idk: I do not know
#     acc: accusative
#       dpd: dependent
#       ind: independent
#       nna: none of the above
#       idk: I do not know
#     vct: vocative
#     nna: none of the above
#     idk: I do not know
#   adj: adjective pronoun
#   nna: none of the above
#   idk: I do not know
# adp: adposition
# noun: noun
#   nmn: nominative
#     dpd: dependent
#     ind: independent
#       ctc: citation
#       pnd: nominativus pendens
#       exc: exclamation
#       nna: none of the above
#       idk: I do not know
#     nna: none of the above
#     idk: I do not know
#   gnt: genitive
#     dpd: dependent
#       prp: proper
#       abl: ablatival
#       tmp__plc: time and place
#       adp: adpositional
#       nna: none of the above
#       idk: I do not know
#     ind: independent
#       exc: exclamation
#       nna: none of the above
#       idk: I do not know
#     nna: none of the above
#     idk: I do not know
#   dtv: dative
#     dpd: dependent
#       prp: proper
#       ins: instrumental
#       lcv: locative
#       adp: adpositional
#       nna: none of the above
#       idk: I do not know
#     nna: none of the above
#     idk: I do not know
#   acc: accusative
#     dpd: dependent
#       eff: internal object
#       aff: external object
#       ext: extent
#       drc: terminal
#       rsp: respect
#       adp: adpositional
#       nna: none of the above
#       idk: I do not know
#     ind: independent
#       ell: elliptical
#       nna: none of the above
#       idk: I do not know
#     nna: none of the above
#     idk: I do not know
#   vct: vocative
#   nna: none of the above
#   idk: I do not know
# verb: verb
#   fnt: finite verb
#     ind: independent
#       stt: statement
#       ass: assumption
#       cmm: command
#       wsh: wish
#       qst: question
#       exc: exclamation
#       nna: none of the above
#       idk: I do not know
#     dpn: dependent
#       sbs__cls: substantive clause
#       adj__cls: adjective clause
#       adv__cls: adverb clause
#       nna: none of the above
#       idk: I do not know
#     nna: none of the above
#     idk: I do not know
#   prt: participle
#     adj: adjective participle
#       atr: attributive
#       crc: circumstantial
#       spl: supplementary
#       prp: periphrastic
#       nna: none of the above
#       idk: I do not know
#     sbs: substantive participle
#       nmn: nominative
#       gnt: genitive
#       dtv: dative
#       acc: accusative
#       vct: vocative
#       nna: none of the above
#       idk: I do not know
#     nna: none of the above
#     idk: I do not know
#   inf: infinitive
#     dpd: dependent
#       art: articular
#       vrb: verbal
#       nna: none of the above
#       idk: I do not know
#     ind: independent
#       cmm: command
#       wsh: wish
#       exc: exclamation
#       abs: absolute
#       nna: none of the above
#       idk: I do not know
#     nna: none of the above
#     idk: I do not know
#   nna: none of the above
#   idk: I do not know
# adv: adverb
#   tmp: time
#     sml__lct: simultaneous location
#     squ__lct: sequential location
#     squ__drt: sequential-durative
#     tmp__dst: temporal distance
#     tmp__ext: temporal extent
#     nna: none of the above
#     idk: I do not know
#   plc: place
#     lct: location
#       cnc: concrete
#       fgr: figurative
#       nna: none of the above
#       idk: I do not know
#     drc: direction
#       cnc: concrete
#       fgr: figurative
#       nna: none of the above
#       idk: I do not know
#     pth: path
#       cnc: concrete
#       fgr: figurative
#       nna: none of the above
#       idk: I do not know
#     spr: separation
#       cnc: concrete
#       fgr: figurative
#       nna: none of the above
#       idk: I do not know
#     nna: none of the above
#     idk: I do not know
#   src: source
#   cau: cause
#   cns: result
#   mnn: manner
#   msr: measure
#   ins__mns: instrument or means
#   fnl: purpose
#   cnc: concession
#   ngt: negation
#   prt: particle
#   nna: none of the above
#   idk: I do not know
# nrl: numeral
#   crd: cardinal
#     adj: adjective
#     sbs: substantive
#       nmn: nominative
#       gnt: genitive
#       dtv: dative
#       acc: accusative
#       vct: vocative
#       nna: none of the above
#       idk: I do not know
#     nna: none of the above
#     idk: I do not know
#   ord: ordinal
#     adj: adjective
#     sbs: substantive
#       nmn: nominative
#       gnt: genitive
#       dtv: dative
#       acc: accusative
#       vct: vocative
#       nna: none of the above
#       idk: I do not know
#     nna: none of the above
#     idk: I do not know
#   adv: adverb
#     tmp: time
#       sml__lct: simultaneous location
#       squ__lct: sequential location
#       squ__drt: sequential-durative
#       tmp__dst: temporal distance
#       tmp__ext: temporal extent
#       nna: none of the above
#       idk: I do not know
#     plc: place
#       lct: location
#       drc: direction
#       pth: path
#       spr: separation
#       nna: none of the above
#       idk: I do not know
#     src: source
#     cau: cause
#     cns: result
#     mnn: manner
#     msr: measure
#     ins__mns: instrument or means
#     fnl: purpose
#     cnc: concession
#     ngt: negation
#     prt: particle
#     nna: none of the above
#     idk: I do not know
#   nna: none of the above
#   idk: I do not know

# %%
# Finest labels
print_children(node, level=10)
# Out:
# adj: adjective
#   prp: adjective proper
#   sbs: substantive adjective
#     nmn: nominative
#       dpd: dependent
#       ind: independent
#         ctc: citation
#         pnd: nominativus pendens
#         exc: exclamation
#         nna: none of the above
#         idk: I do not know
#       nna: none of the above
#       idk: I do not know
#     gnt: genitive
#       dpd: dependent
#         prp: proper
#           pss__bln: possession or belonging
#           dvd: divided whole
#           qlt: quality
#           exp: explanation
#           mtr__cnt: material or contents
#           msr: measure
#             tmp: time
#             spc: space
#             dgr: degree
#             nna: none of the above
#             idk: I do not know
#           sbj__obj: subjective or objective
#             sbj: subjective
#             obj: objective
#             nna: none of the above
#             idk: I do not know
#           prc__val: price and value
#           crm__acn: crime and accountability
#           tpc: topic
#           cnn: connection
#           nna: none of the above
#           idk: I do not know
#         abl: ablatival
#           spr: separation
#             cnc: concrete
#             fgr: figurative
#             nna: none of the above
#             idk: I do not know
#           dst__cmp: distinction and comparison
#           cau: cause
#           fnl: purpose
#           src: source
#           nna: none of the above
#           idk: I do not know
#         tmp__plc: time and place
#           tmp: time
#             sml__lct: simultaneous location
#             squ__lct: sequential location
#             squ__drt: sequential-durative
#             tmp__dst: temporal distance
#             tmp__ext: temporal extent
#             nna: none of the above
#             idk: I do not know
#           plc: place
#             lct: location
#               cnc: concrete
#               fgr: figurative
#               nna: none of the above
#               idk: I do not know
#             drc: direction
#               cnc: concrete
#               fgr: figurative
#               nna: none of the above
#               idk: I do not know
#             pth: path
#               cnc: concrete
#               fgr: figurative
#               nna: none of the above
#               idk: I do not know
#             nna: none of the above
#             idk: I do not know
#           nna: none of the above
#           idk: I do not know
#         adp: adpositional
#           ins__mns: instrument or means
#           agt: agent
#           mnn: manner
#           frd__ass: friendly association
#           hst__ass: hostile association
#           acm: accompaniment
#           acm__crc: accompanying circumstance
#           adv: advantage
#           dsd: disadvantage
#           rfr: reference
#           cnf: conformity
#           nna: none of the above
#           idk: I do not know
#         nna: none of the above
#         idk: I do not know
#       ind: independent
#         exc: exclamation
#         nna: none of the above
#         idk: I do not know
#       nna: none of the above
#       idk: I do not know
#     dtv: dative
#       dpd: dependent
#         prp: proper
#           drc: direct complement of verbs
#           ind: indirect complement of verbs
#           int: interest
#             pss: possessor
#             adv: advantage
#             dsd: disadvantage
#             fln: feeling
#             inc__avr: with participle of inclination or aversion
#             agn: agent
#             nna: none of the above
#             idk: I do not know
#           rlt: relation
#             prp: proper
#             rfr: reference
#             exp__tmp: with a participle of expressing time
#             nna: none of the above
#             idk: I do not know
#           nna: none of the above
#           idk: I do not know
#         ins: instrumental
#           prp: proper
#             ins__mns: instrument or means
#             stn__jdg: standard of judgement
#             mnn: manner
#             msr__dff: measure of difference
#             rsp: respect
#             cau: cause
#             nna: none of the above
#             idk: I do not know
#           cmt: comitative
#             frd__ass: friendly association
#             hst__ass: hostile association
#             acm: accompaniment
#             acm__crc: accompanying circumstance
#             nna: none of the above
#             idk: I do not know
#           nna: none of the above
#           idk: I do not know
#         lcv: locative
#           plc: place
#             lct: location
#               cnc: concrete
#               fgr: figurative
#               nna: none of the above
#               idk: I do not know
#             drc: direction
#               cnc: concrete
#               fgr: figurative
#               nna: none of the above
#               idk: I do not know
#             pth: path
#               cnc: concrete
#               fgr: figurative
#               nna: none of the above
#               idk: I do not know
#             nna: none of the above
#             idk: I do not know
#           tmp: time
#             sml__lct: simultaneous location
#             squ__lct: sequential location
#             squ__drt: sequential-durative
#             tmp__dst: temporal distance
#             tmp__ext: temporal extent
#             nna: none of the above
#             idk: I do not know
#           nna: none of the above
#           idk: I do not know
#         adp: adpositional
#           fnl: purpose
#           cnf: conformity
#           prc__val: price and value
#           cnd: condition
#           nna: none of the above
#           idk: I do not know
#         nna: none of the above
#         idk: I do not know
#       nna: none of the above
#       idk: I do not know
#     acc: accusative
#       dpd: dependent
#         eff: internal object
#         aff: external object
#         ext: extent
#           spc: space
#             lct: location
#               cnc: concrete
#               fgr: figurative
#               nna: none of the above
#               idk: I do not know
#             pth: path
#               cnc: concrete
#               fgr: figurative
#               nna: none of the above
#               idk: I do not know
#             nna: none of the above
#             idk: I do not know
#           tmp: time
#             sml__lct: simultaneous location
#             squ__lct: sequential location
#             squ__drt: sequential-durative
#             tmp__dst: temporal distance
#             tmp__ext: temporal extent
#             nna: none of the above
#             idk: I do not know
#           msr: measure
#           nna: none of the above
#           idk: I do not know
#         drc: terminal
#           cnc: concrete
#           fgr: figurative
#           nna: none of the above
#           idk: I do not know
#         rsp: respect
#         adp: adpositional
#           mnn: manner
#           ins__mns: instrument or means
#           cau: cause
#           fnl: purpose
#           stn__jdg: standard of judgement
#           cmp: comparison
#           adv: advantage
#           dsd: disadvantage
#           rcp__add: recipient or addressee
#           cnf: conformity
#           frd__ass: friendly association
#           hst__ass: hostile association
#           nna: none of the above
#           idk: I do not know
#         nna: none of the above
#         idk: I do not know
#       ind: independent
#         ell: elliptical
#         nna: none of the above
#         idk: I do not know
#       nna: none of the above
#       idk: I do not know
#     vct: vocative
#     nna: none of the above
#     idk: I do not know
#   vrb__prp: verbal adjective proper
#   vrb__sbs: substantive verbal adjective
#     nmn: nominative
#       dpd: dependent
#       ind: independent
#         ctc: citation
#         pnd: nominativus pendens
#         exc: exclamation
#         nna: none of the above
#         idk: I do not know
#       nna: none of the above
#       idk: I do not know
#     gnt: genitive
#       dpd: dependent
#         prp: proper
#           pss__bln: possession or belonging
#           dvd: divided whole
#           qlt: quality
#           exp: explanation
#           mtr__cnt: material or contents
#           msr: measure
#             tmp: time
#             spc: space
#             dgr: degree
#             nna: none of the above
#             idk: I do not know
#           sbj__obj: subjective or objective
#             sbj: subjective
#             obj: objective
#             nna: none of the above
#             idk: I do not know
#           prc__val: price and value
#           crm__acn: crime and accountability
#           tpc: topic
#           cnn: connection
#           nna: none of the above
#           idk: I do not know
#         abl: ablatival
#           spr: separation
#             cnc: concrete
#             fgr: figurative
#             nna: none of the above
#             idk: I do not know
#           dst__cmp: distinction and comparison
#           cau: cause
#           fnl: purpose
#           src: source
#           nna: none of the above
#           idk: I do not know
#         tmp__plc: time and place
#           tmp: time
#             sml__lct: simultaneous location
#             squ__lct: sequential location
#             squ__drt: sequential-durative
#             tmp__dst: temporal distance
#             tmp__ext: temporal extent
#             nna: none of the above
#             idk: I do not know
#           plc: place
#             lct: location
#               cnc: concrete
#               fgr: figurative
#               nna: none of the above
#               idk: I do not know
#             drc: direction
#               cnc: concrete
#               fgr: figurative
#               nna: none of the above
#               idk: I do not know
#             pth: path
#               cnc: concrete
#               fgr: figurative
#               nna: none of the above
#               idk: I do not know
#             nna: none of the above
#             idk: I do not know
#           nna: none of the above
#           idk: I do not know
#         adp: adpositional
#           ins__mns: instrument or means
#           agt: agent
#           mnn: manner
#           frd__ass: friendly association
#           hst__ass: hostile association
#           acm: accompaniment
#           acm__crc: accompanying circumstance
#           adv: advantage
#           dsd: disadvantage
#           rfr: reference
#           cnf: conformity
#           nna: none of the above
#           idk: I do not know
#         nna: none of the above
#         idk: I do not know
#       ind: independent
#         exc: exclamation
#         nna: none of the above
#         idk: I do not know
#       nna: none of the above
#       idk: I do not know
#     dtv: dative
#       dpd: dependent
#         prp: proper
#           drc: direct complement of verbs
#           ind: indirect complement of verbs
#           int: interest
#             pss: possessor
#             adv: advantage
#             dsd: disadvantage
#             fln: feeling
#             inc__avr: with participle of inclination or aversion
#             agn: agent
#             nna: none of the above
#             idk: I do not know
#           rlt: relation
#             prp: proper
#             rfr: reference
#             exp__tmp: with a participle of expressing time
#             nna: none of the above
#             idk: I do not know
#           nna: none of the above
#           idk: I do not know
#         ins: instrumental
#           prp: proper
#             ins__mns: instrument or means
#             stn__jdg: standard of judgement
#             mnn: manner
#             msr__dff: measure of difference
#             rsp: respect
#             cau: cause
#             nna: none of the above
#             idk: I do not know
#           cmt: comitative
#             frd__ass: friendly association
#             hst__ass: hostile association
#             acm: accompaniment
#             acm__crc: accompanying circumstance
#             nna: none of the above
#             idk: I do not know
#           nna: none of the above
#           idk: I do not know
#         lcv: locative
#           plc: place
#             lct: location
#               cnc: concrete
#               fgr: figurative
#               nna: none of the above
#               idk: I do not know
#             drc: direction
#               cnc: concrete
#               fgr: figurative
#               nna: none of the above
#               idk: I do not know
#             pth: path
#               cnc: concrete
#               fgr: figurative
#               nna: none of the above
#               idk: I do not know
#             nna: none of the above
#             idk: I do not know
#           tmp: time
#             sml__lct: simultaneous location
#             squ__lct: sequential location
#             squ__drt: sequential-durative
#             tmp__dst: temporal distance
#             tmp__ext: temporal extent
#             nna: none of the above
#             idk: I do not know
#           nna: none of the above
#           idk: I do not know
#         adp: adpositional
#           fnl: purpose
#           cnf: conformity
#           prc__val: price and value
#           cnd: condition
#           nna: none of the above
#           idk: I do not know
#         nna: none of the above
#         idk: I do not know
#       nna: none of the above
#       idk: I do not know
#     acc: accusative
#       dpd: dependent
#         eff: internal object
#         aff: external object
#         ext: extent
#           spc: space
#             lct: location
#               cnc: concrete
#               fgr: figurative
#               nna: none of the above
#               idk: I do not know
#             pth: path
#               cnc: concrete
#               fgr: figurative
#               nna: none of the above
#               idk: I do not know
#             nna: none of the above
#             idk: I do not know
#           tmp: time
#             sml__lct: simultaneous location
#             squ__lct: sequential location
#             squ__drt: sequential-durative
#             tmp__dst: temporal distance
#             tmp__ext: temporal extent
#             nna: none of the above
#             idk: I do not know
#           msr: measure
#           nna: none of the above
#           idk: I do not know
#         drc: terminal
#           cnc: concrete
#           fgr: figurative
#           nna: none of the above
#           idk: I do not know
#         rsp: respect
#         adp: adpositional
#           mnn: manner
#           ins__mns: instrument or means
#           cau: cause
#           fnl: purpose
#           stn__jdg: standard of judgement
#           cmp: comparison
#           adv: advantage
#           dsd: disadvantage
#           rcp__add: recipient or addressee
#           cnf: conformity
#           frd__ass: friendly association
#           hst__ass: hostile association
#           nna: none of the above
#           idk: I do not know
#         nna: none of the above
#         idk: I do not know
#       ind: independent
#         ell: elliptical
#         nna: none of the above
#         idk: I do not know
#       nna: none of the above
#       idk: I do not know
#     vct: vocative
#     nna: none of the above
#     idk: I do not know
#   nna: none of the above
#   idk: I do not know
# art: article
# prn: pronoun
#   sbs: substantive pronoun
#     nmn: nominative
#       dpd: dependent
#       ind: independent
#         ctc: citation
#         pnd: nominativus pendens
#         exc: exclamation
#         nna: none of the above
#         idk: I do not know
#       nna: none of the above
#       idk: I do not know
#     gnt: genitive
#       dpd: dependent
#         prp: proper
#           pss__bln: possession or belonging
#           dvd: divided whole
#           qlt: quality
#           exp: explanation
#           mtr__cnt: material or contents
#           msr: measure
#             tmp: time
#             spc: space
#             dgr: degree
#             nna: none of the above
#             idk: I do not know
#           sbj__obj: subjective or objective
#             sbj: subjective
#             obj: objective
#             nna: none of the above
#             idk: I do not know
#           prc__val: price and value
#           crm__acn: crime and accountability
#           tpc: topic
#           cnn: connection
#           nna: none of the above
#           idk: I do not know
#         abl: ablatival
#           spr: separation
#             cnc: concrete
#             fgr: figurative
#             nna: none of the above
#             idk: I do not know
#           dst__cmp: distinction and comparison
#           cau: cause
#           fnl: purpose
#           src: source
#           nna: none of the above
#           idk: I do not know
#         tmp__plc: time and place
#           tmp: time
#             sml__lct: simultaneous location
#             squ__lct: sequential location
#             squ__drt: sequential-durative
#             tmp__dst: temporal distance
#             tmp__ext: temporal extent
#             nna: none of the above
#             idk: I do not know
#           plc: place
#             lct: location
#               cnc: concrete
#               fgr: figurative
#               nna: none of the above
#               idk: I do not know
#             drc: direction
#               cnc: concrete
#               fgr: figurative
#               nna: none of the above
#               idk: I do not know
#             pth: path
#               cnc: concrete
#               fgr: figurative
#               nna: none of the above
#               idk: I do not know
#             nna: none of the above
#             idk: I do not know
#           nna: none of the above
#           idk: I do not know
#         adp: adpositional
#           ins__mns: instrument or means
#           agt: agent
#           mnn: manner
#           frd__ass: friendly association
#           hst__ass: hostile association
#           acm: accompaniment
#           acm__crc: accompanying circumstance
#           adv: advantage
#           dsd: disadvantage
#           rfr: reference
#           cnf: conformity
#           nna: none of the above
#           idk: I do not know
#         nna: none of the above
#         idk: I do not know
#       ind: independent
#         exc: exclamation
#         nna: none of the above
#         idk: I do not know
#       nna: none of the above
#       idk: I do not know
#     dtv: dative
#       dpd: dependent
#         prp: proper
#           drc: direct complement of verbs
#           ind: indirect complement of verbs
#           int: interest
#             pss: possessor
#             adv: advantage
#             dsd: disadvantage
#             fln: feeling
#             inc__avr: with participle of inclination or aversion
#             agn: agent
#             nna: none of the above
#             idk: I do not know
#           rlt: relation
#             prp: proper
#             rfr: reference
#             exp__tmp: with a participle of expressing time
#             nna: none of the above
#             idk: I do not know
#           nna: none of the above
#           idk: I do not know
#         ins: instrumental
#           prp: proper
#             ins__mns: instrument or means
#             stn__jdg: standard of judgement
#             mnn: manner
#             msr__dff: measure of difference
#             rsp: respect
#             cau: cause
#             nna: none of the above
#             idk: I do not know
#           cmt: comitative
#             frd__ass: friendly association
#             hst__ass: hostile association
#             acm: accompaniment
#             acm__crc: accompanying circumstance
#             nna: none of the above
#             idk: I do not know
#           nna: none of the above
#           idk: I do not know
#         lcv: locative
#           plc: place
#             lct: location
#               cnc: concrete
#               fgr: figurative
#               nna: none of the above
#               idk: I do not know
#             drc: direction
#               cnc: concrete
#               fgr: figurative
#               nna: none of the above
#               idk: I do not know
#             pth: path
#               cnc: concrete
#               fgr: figurative
#               nna: none of the above
#               idk: I do not know
#             nna: none of the above
#             idk: I do not know
#           tmp: time
#             sml__lct: simultaneous location
#             squ__lct: sequential location
#             squ__drt: sequential-durative
#             tmp__dst: temporal distance
#             tmp__ext: temporal extent
#             nna: none of the above
#             idk: I do not know
#           nna: none of the above
#           idk: I do not know
#         adp: adpositional
#           fnl: purpose
#           cnf: conformity
#           prc__val: price and value
#           cnd: condition
#           nna: none of the above
#           idk: I do not know
#         nna: none of the above
#         idk: I do not know
#       nna: none of the above
#       idk: I do not know
#     acc: accusative
#       dpd: dependent
#         eff: internal object
#         aff: external object
#         ext: extent
#           spc: space
#             lct: location
#               cnc: concrete
#               fgr: figurative
#               nna: none of the above
#               idk: I do not know
#             pth: path
#               cnc: concrete
#               fgr: figurative
#               nna: none of the above
#               idk: I do not know
#             nna: none of the above
#             idk: I do not know
#           tmp: time
#             sml__lct: simultaneous location
#             squ__lct: sequential location
#             squ__drt: sequential-durative
#             tmp__dst: temporal distance
#             tmp__ext: temporal extent
#             nna: none of the above
#             idk: I do not know
#           msr: measure
#           nna: none of the above
#           idk: I do not know
#         drc: terminal
#           cnc: concrete
#           fgr: figurative
#           nna: none of the above
#           idk: I do not know
#         rsp: respect
#         adp: adpositional
#           mnn: manner
#           ins__mns: instrument or means
#           cau: cause
#           fnl: purpose
#           stn__jdg: standard of judgement
#           cmp: comparison
#           adv: advantage
#           dsd: disadvantage
#           rcp__add: recipient or addressee
#           cnf: conformity
#           frd__ass: friendly association
#           hst__ass: hostile association
#           nna: none of the above
#           idk: I do not know
#         nna: none of the above
#         idk: I do not know
#       ind: independent
#         ell: elliptical
#         nna: none of the above
#         idk: I do not know
#       nna: none of the above
#       idk: I do not know
#     vct: vocative
#     nna: none of the above
#     idk: I do not know
#   adj: adjective pronoun
#   nna: none of the above
#   idk: I do not know
# adp: adposition
# noun: noun
#   nmn: nominative
#     dpd: dependent
#     ind: independent
#       ctc: citation
#       pnd: nominativus pendens
#       exc: exclamation
#       nna: none of the above
#       idk: I do not know
#     nna: none of the above
#     idk: I do not know
#   gnt: genitive
#     dpd: dependent
#       prp: proper
#         pss__bln: possession or belonging
#         dvd: divided whole
#         qlt: quality
#         exp: explanation
#         mtr__cnt: material or contents
#         msr: measure
#           tmp: time
#           spc: space
#           dgr: degree
#           nna: none of the above
#           idk: I do not know
#         sbj__obj: subjective or objective
#           sbj: subjective
#           obj: objective
#           nna: none of the above
#           idk: I do not know
#         prc__val: price and value
#         crm__acn: crime and accountability
#         tpc: topic
#         cnn: connection
#         nna: none of the above
#         idk: I do not know
#       abl: ablatival
#         spr: separation
#           cnc: concrete
#           fgr: figurative
#           nna: none of the above
#           idk: I do not know
#         dst__cmp: distinction and comparison
#         cau: cause
#         fnl: purpose
#         src: source
#         nna: none of the above
#         idk: I do not know
#       tmp__plc: time and place
#         tmp: time
#           sml__lct: simultaneous location
#           squ__lct: sequential location
#           squ__drt: sequential-durative
#           tmp__dst: temporal distance
#           tmp__ext: temporal extent
#           nna: none of the above
#           idk: I do not know
#         plc: place
#           lct: location
#             cnc: concrete
#             fgr: figurative
#             nna: none of the above
#             idk: I do not know
#           drc: direction
#             cnc: concrete
#             fgr: figurative
#             nna: none of the above
#             idk: I do not know
#           pth: path
#             cnc: concrete
#             fgr: figurative
#             nna: none of the above
#             idk: I do not know
#           nna: none of the above
#           idk: I do not know
#         nna: none of the above
#         idk: I do not know
#       adp: adpositional
#         ins__mns: instrument or means
#         agt: agent
#         mnn: manner
#         frd__ass: friendly association
#         hst__ass: hostile association
#         acm: accompaniment
#         acm__crc: accompanying circumstance
#         adv: advantage
#         dsd: disadvantage
#         rfr: reference
#         cnf: conformity
#         nna: none of the above
#         idk: I do not know
#       nna: none of the above
#       idk: I do not know
#     ind: independent
#       exc: exclamation
#       nna: none of the above
#       idk: I do not know
#     nna: none of the above
#     idk: I do not know
#   dtv: dative
#     dpd: dependent
#       prp: proper
#         drc: direct complement of verbs
#         ind: indirect complement of verbs
#         int: interest
#           pss: possessor
#           adv: advantage
#           dsd: disadvantage
#           fln: feeling
#           inc__avr: with participle of inclination or aversion
#           agn: agent
#           nna: none of the above
#           idk: I do not know
#         rlt: relation
#           prp: proper
#           rfr: reference
#           exp__tmp: with a participle of expressing time
#           nna: none of the above
#           idk: I do not know
#         nna: none of the above
#         idk: I do not know
#       ins: instrumental
#         prp: proper
#           ins__mns: instrument or means
#           stn__jdg: standard of judgement
#           mnn: manner
#           msr__dff: measure of difference
#           rsp: respect
#           cau: cause
#           nna: none of the above
#           idk: I do not know
#         cmt: comitative
#           frd__ass: friendly association
#           hst__ass: hostile association
#           acm: accompaniment
#           acm__crc: accompanying circumstance
#           nna: none of the above
#           idk: I do not know
#         nna: none of the above
#         idk: I do not know
#       lcv: locative
#         plc: place
#           lct: location
#             cnc: concrete
#             fgr: figurative
#             nna: none of the above
#             idk: I do not know
#           drc: direction
#             cnc: concrete
#             fgr: figurative
#             nna: none of the above
#             idk: I do not know
#           pth: path
#             cnc: concrete
#             fgr: figurative
#             nna: none of the above
#             idk: I do not know
#           nna: none of the above
#           idk: I do not know
#         tmp: time
#           sml__lct: simultaneous location
#           squ__lct: sequential location
#           squ__drt: sequential-durative
#           tmp__dst: temporal distance
#           tmp__ext: temporal extent
#           nna: none of the above
#           idk: I do not know
#         nna: none of the above
#         idk: I do not know
#       adp: adpositional
#         fnl: purpose
#         cnf: conformity
#         prc__val: price and value
#         cnd: condition
#         nna: none of the above
#         idk: I do not know
#       nna: none of the above
#       idk: I do not know
#     nna: none of the above
#     idk: I do not know
#   acc: accusative
#     dpd: dependent
#       eff: internal object
#       aff: external object
#       ext: extent
#         spc: space
#           lct: location
#             cnc: concrete
#             fgr: figurative
#             nna: none of the above
#             idk: I do not know
#           pth: path
#             cnc: concrete
#             fgr: figurative
#             nna: none of the above
#             idk: I do not know
#           nna: none of the above
#           idk: I do not know
#         tmp: time
#           sml__lct: simultaneous location
#           squ__lct: sequential location
#           squ__drt: sequential-durative
#           tmp__dst: temporal distance
#           tmp__ext: temporal extent
#           nna: none of the above
#           idk: I do not know
#         msr: measure
#         nna: none of the above
#         idk: I do not know
#       drc: terminal
#         cnc: concrete
#         fgr: figurative
#         nna: none of the above
#         idk: I do not know
#       rsp: respect
#       adp: adpositional
#         mnn: manner
#         ins__mns: instrument or means
#         cau: cause
#         fnl: purpose
#         stn__jdg: standard of judgement
#         cmp: comparison
#         adv: advantage
#         dsd: disadvantage
#         rcp__add: recipient or addressee
#         cnf: conformity
#         frd__ass: friendly association
#         hst__ass: hostile association
#         nna: none of the above
#         idk: I do not know
#       nna: none of the above
#       idk: I do not know
#     ind: independent
#       ell: elliptical
#       nna: none of the above
#       idk: I do not know
#     nna: none of the above
#     idk: I do not know
#   vct: vocative
#   nna: none of the above
#   idk: I do not know
# verb: verb
#   fnt: finite verb
#     ind: independent
#       stt: statement
#       ass: assumption
#       cmm: command
#       wsh: wish
#       qst: question
#       exc: exclamation
#       nna: none of the above
#       idk: I do not know
#     dpn: dependent
#       sbs__cls: substantive clause
#         stt: statement
#           ind: in indirect discourse
#           not__ind: not in indirect discourse
#           nna: none of the above
#           idk: I do not know
#         wll__dsr: will or desire
#           ind: in indirect discourse
#           not__ind: not in indirect discourse
#           nna: none of the above
#           idk: I do not know
#         qst: question
#           ind: in indirect discourse
#           not__ind: not in indirect discourse
#           nna: none of the above
#           idk: I do not know
#         exc: exclamation
#           ind: in indirect discourse
#           not__ind: not in indirect discourse
#           nna: none of the above
#           idk: I do not know
#         nna: none of the above
#         idk: I do not know
#       adj__cls: adjective clause
#         prp: adjective clause proper
#           ord: ordinary relative clause
#             ind: in indirect discourse
#             not__ind: not in indirect discourse
#             nna: none of the above
#             idk: I do not know
#           fnl: final relative clause
#             ind: in indirect discourse
#             not__ind: not in indirect discourse
#             nna: none of the above
#             idk: I do not know
#           cau: cause relative clause
#             ind: in indirect discourse
#             not__ind: not in indirect discourse
#             nna: none of the above
#             idk: I do not know
#           cns: consecutive relative clause
#             ind: in indirect discourse
#             not__ind: not in indirect discourse
#             nna: none of the above
#             idk: I do not know
#           cnd: conditional relative clause
#             ind: in indirect discourse
#             not__ind: not in indirect discourse
#             nna: none of the above
#             idk: I do not know
#           nna: none of the above
#           idk: I do not know
#         sbs: substantivized adjective clause
#           ind: in indirect discourse
#             nmn: nominative
#               dpd: dependent
#               ind: independent
#                 ctc: citation
#                 pnd: nominativus pendens
#                 exc: exclamation
#                 nna: none of the above
#                 idk: I do not know
#               nna: none of the above
#               idk: I do not know
#             gnt: genitive
#               dpd: dependent
#                 prp: proper
#                   pss__bln: possession or belonging
#                   dvd: divided whole
#                   qlt: quality
#                   exp: explanation
#                   mtr__cnt: material or contents
#                   msr: measure
#                     tmp: time
#                     spc: space
#                     dgr: degree
#                     nna: none of the above
#                     idk: I do not know
#                   sbj__obj: subjective or objective
#                     sbj: subjective
#                     obj: objective
#                     nna: none of the above
#                     idk: I do not know
#                   prc__val: price and value
#                   crm__acn: crime and accountability
#                   tpc: topic
#                   cnn: connection
#                   nna: none of the above
#                   idk: I do not know
#                 abl: ablatival
#                   spr: separation
#                     cnc: concrete
#                     fgr: figurative
#                     nna: none of the above
#                     idk: I do not know
#                   dst__cmp: distinction and comparison
#                   cau: cause
#                   fnl: purpose
#                   src: source
#                   nna: none of the above
#                   idk: I do not know
#                 tmp__plc: time and place
#                   tmp: time
#                     sml__lct: simultaneous location
#                     squ__lct: sequential location
#                     squ__drt: sequential-durative
#                     tmp__dst: temporal distance
#                     tmp__ext: temporal extent
#                     nna: none of the above
#                     idk: I do not know
#                   plc: place
#                     lct: location
#                     drc: direction
#                     pth: path
#                     nna: none of the above
#                     idk: I do not know
#                   nna: none of the above
#                   idk: I do not know
#                 adp: adpositional
#                   ins__mns: instrument or means
#                   agt: agent
#                   mnn: manner
#                   frd__ass: friendly association
#                   hst__ass: hostile association
#                   acm: accompaniment
#                   acm__crc: accompanying circumstance
#                   adv: advantage
#                   dsd: disadvantage
#                   rfr: reference
#                   cnf: conformity
#                   nna: none of the above
#                   idk: I do not know
#                 nna: none of the above
#                 idk: I do not know
#               ind: independent
#                 exc: exclamation
#                 nna: none of the above
#                 idk: I do not know
#               nna: none of the above
#               idk: I do not know
#             dtv: dative
#               dpd: dependent
#                 prp: proper
#                   drc: direct complement of verbs
#                   ind: indirect complement of verbs
#                   int: interest
#                     pss: possessor
#                     adv: advantage
#                     dsd: disadvantage
#                     fln: feeling
#                     inc__avr: with participle of inclination or aversion
#                     agn: agent
#                     nna: none of the above
#                     idk: I do not know
#                   rlt: relation
#                     prp: proper
#                     rfr: reference
#                     exp__tmp: with a participle of expressing time
#                     nna: none of the above
#                     idk: I do not know
#                   nna: none of the above
#                   idk: I do not know
#                 ins: instrumental
#                   prp: proper
#                     ins__mns: instrument or means
#                     stn__jdg: standard of judgement
#                     mnn: manner
#                     msr__dff: measure of difference
#                     rsp: respect
#                     cau: cause
#                     nna: none of the above
#                     idk: I do not know
#                   cmt: comitative
#                     frd__ass: friendly association
#                     hst__ass: hostile association
#                     acm: accompaniment
#                     acm__crc: accompanying circumstance
#                     nna: none of the above
#                     idk: I do not know
#                   nna: none of the above
#                   idk: I do not know
#                 lcv: locative
#                   plc: place
#                     lct: location
#                     drc: direction
#                     pth: path
#                     nna: none of the above
#                     idk: I do not know
#                   tmp: time
#                     sml__lct: simultaneous location
#                     squ__lct: sequential location
#                     squ__drt: sequential-durative
#                     tmp__dst: temporal distance
#                     tmp__ext: temporal extent
#                     nna: none of the above
#                     idk: I do not know
#                   nna: none of the above
#                   idk: I do not know
#                 adp: adpositional
#                   fnl: purpose
#                   cnf: conformity
#                   prc__val: price and value
#                   cnd: condition
#                   nna: none of the above
#                   idk: I do not know
#                 nna: none of the above
#                 idk: I do not know
#               nna: none of the above
#               idk: I do not know
#             acc: accusative
#               dpd: dependent
#                 eff: internal object
#                 aff: external object
#                 ext: extent
#                   spc: space
#                     lct: location
#                     pth: path
#                     nna: none of the above
#                     idk: I do not know
#                   tmp: time
#                     sml__lct: simultaneous location
#                     squ__lct: sequential location
#                     squ__drt: sequential-durative
#                     tmp__dst: temporal distance
#                     tmp__ext: temporal extent
#                     nna: none of the above
#                     idk: I do not know
#                   msr: measure
#                   nna: none of the above
#                   idk: I do not know
#                 drc: terminal
#                   cnc: concrete
#                   fgr: figurative
#                   nna: none of the above
#                   idk: I do not know
#                 rsp: respect
#                 adp: adpositional
#                   mnn: manner
#                   ins__mns: instrument or means
#                   cau: cause
#                   fnl: purpose
#                   stn__jdg: standard of judgement
#                   cmp: comparison
#                   adv: advantage
#                   dsd: disadvantage
#                   rcp__add: recipient or addressee
#                   cnf: conformity
#                   frd__ass: friendly association
#                   hst__ass: hostile association
#                   nna: none of the above
#                   idk: I do not know
#                 nna: none of the above
#                 idk: I do not know
#               ind: independent
#                 ell: elliptical
#                 nna: none of the above
#                 idk: I do not know
#               nna: none of the above
#               idk: I do not know
#             vct: vocative
#             nna: none of the above
#             idk: I do not know
#           not__ind: not in indirect discourse
#             nmn: nominative
#               dpd: dependent
#               ind: independent
#                 ctc: citation
#                 pnd: nominativus pendens
#                 exc: exclamation
#                 nna: none of the above
#                 idk: I do not know
#               nna: none of the above
#               idk: I do not know
#             gnt: genitive
#               dpd: dependent
#                 prp: proper
#                   pss__bln: possession or belonging
#                   dvd: divided whole
#                   qlt: quality
#                   exp: explanation
#                   mtr__cnt: material or contents
#                   msr: measure
#                     tmp: time
#                     spc: space
#                     dgr: degree
#                     nna: none of the above
#                     idk: I do not know
#                   sbj__obj: subjective or objective
#                     sbj: subjective
#                     obj: objective
#                     nna: none of the above
#                     idk: I do not know
#                   prc__val: price and value
#                   crm__acn: crime and accountability
#                   tpc: topic
#                   cnn: connection
#                   nna: none of the above
#                   idk: I do not know
#                 abl: ablatival
#                   spr: separation
#                     cnc: concrete
#                     fgr: figurative
#                     nna: none of the above
#                     idk: I do not know
#                   dst__cmp: distinction and comparison
#                   cau: cause
#                   fnl: purpose
#                   src: source
#                   nna: none of the above
#                   idk: I do not know
#                 tmp__plc: time and place
#                   tmp: time
#                     sml__lct: simultaneous location
#                     squ__lct: sequential location
#                     squ__drt: sequential-durative
#                     tmp__dst: temporal distance
#                     tmp__ext: temporal extent
#                     nna: none of the above
#                     idk: I do not know
#                   plc: place
#                     lct: location
#                     drc: direction
#                     pth: path
#                     nna: none of the above
#                     idk: I do not know
#                   nna: none of the above
#                   idk: I do not know
#                 adp: adpositional
#                   ins__mns: instrument or means
#                   agt: agent
#                   mnn: manner
#                   frd__ass: friendly association
#                   hst__ass: hostile association
#                   acm: accompaniment
#                   acm__crc: accompanying circumstance
#                   adv: advantage
#                   dsd: disadvantage
#                   rfr: reference
#                   cnf: conformity
#                   nna: none of the above
#                   idk: I do not know
#                 nna: none of the above
#                 idk: I do not know
#               ind: independent
#                 exc: exclamation
#                 nna: none of the above
#                 idk: I do not know
#               nna: none of the above
#               idk: I do not know
#             dtv: dative
#               dpd: dependent
#                 prp: proper
#                   drc: direct complement of verbs
#                   ind: indirect complement of verbs
#                   int: interest
#                     pss: possessor
#                     adv: advantage
#                     dsd: disadvantage
#                     fln: feeling
#                     inc__avr: with participle of inclination or aversion
#                     agn: agent
#                     nna: none of the above
#                     idk: I do not know
#                   rlt: relation
#                     prp: proper
#                     rfr: reference
#                     exp__tmp: with a participle of expressing time
#                     nna: none of the above
#                     idk: I do not know
#                   nna: none of the above
#                   idk: I do not know
#                 ins: instrumental
#                   prp: proper
#                     ins__mns: instrument or means
#                     stn__jdg: standard of judgement
#                     mnn: manner
#                     msr__dff: measure of difference
#                     rsp: respect
#                     cau: cause
#                     nna: none of the above
#                     idk: I do not know
#                   cmt: comitative
#                     frd__ass: friendly association
#                     hst__ass: hostile association
#                     acm: accompaniment
#                     acm__crc: accompanying circumstance
#                     nna: none of the above
#                     idk: I do not know
#                   nna: none of the above
#                   idk: I do not know
#                 lcv: locative
#                   plc: place
#                     lct: location
#                     drc: direction
#                     pth: path
#                     nna: none of the above
#                     idk: I do not know
#                   tmp: time
#                     sml__lct: simultaneous location
#                     squ__lct: sequential location
#                     squ__drt: sequential-durative
#                     tmp__dst: temporal distance
#                     tmp__ext: temporal extent
#                     nna: none of the above
#                     idk: I do not know
#                   nna: none of the above
#                   idk: I do not know
#                 adp: adpositional
#                   fnl: purpose
#                   cnf: conformity
#                   prc__val: price and value
#                   cnd: condition
#                   nna: none of the above
#                   idk: I do not know
#                 nna: none of the above
#                 idk: I do not know
#               nna: none of the above
#               idk: I do not know
#             acc: accusative
#               dpd: dependent
#                 eff: internal object
#                 aff: external object
#                 ext: extent
#                   spc: space
#                     lct: location
#                     pth: path
#                     nna: none of the above
#                     idk: I do not know
#                   tmp: time
#                     sml__lct: simultaneous location
#                     squ__lct: sequential location
#                     squ__drt: sequential-durative
#                     tmp__dst: temporal distance
#                     tmp__ext: temporal extent
#                     nna: none of the above
#                     idk: I do not know
#                   msr: measure
#                   nna: none of the above
#                   idk: I do not know
#                 drc: terminal
#                   cnc: concrete
#                   fgr: figurative
#                   nna: none of the above
#                   idk: I do not know
#                 rsp: respect
#                 adp: adpositional
#                   mnn: manner
#                   ins__mns: instrument or means
#                   cau: cause
#                   fnl: purpose
#                   stn__jdg: standard of judgement
#                   cmp: comparison
#                   adv: advantage
#                   dsd: disadvantage
#                   rcp__add: recipient or addressee
#                   cnf: conformity
#                   frd__ass: friendly association
#                   hst__ass: hostile association
#                   nna: none of the above
#                   idk: I do not know
#                 nna: none of the above
#                 idk: I do not know
#               ind: independent
#                 ell: elliptical
#                 nna: none of the above
#                 idk: I do not know
#               nna: none of the above
#               idk: I do not know
#             vct: vocative
#             nna: none of the above
#             idk: I do not know
#           nna: none of the above
#           idk: I do not know
#         nna: none of the above
#         idk: I do not know
#       adv__cls: adverb clause
#         fnl: final clause
#           ind: in indirect discourse
#           not__ind: not in indirect discourse
#           nna: none of the above
#           idk: I do not know
#         cau: causal clause
#           ind: in indirect discourse
#           not__ind: not in indirect discourse
#           nna: none of the above
#           idk: I do not know
#         cns: consecutive clause
#           ind: in indirect discourse
#           not__ind: not in indirect discourse
#           nna: none of the above
#           idk: I do not know
#         cnd: conditional clause
#           ind: in indirect discourse
#           not__ind: not in indirect discourse
#           nna: none of the above
#           idk: I do not know
#         cnc: concessive clause
#           ind: in indirect discourse
#           not__ind: not in indirect discourse
#           nna: none of the above
# ...
#               obj: objective
#               nna: none of the above
#               idk: I do not know
#             prc__val: price and value
#             crm__acn: crime and accountability
#             tpc: topic
#             cnn: connection
#             nna: none of the above
#             idk: I do not know
#           abl: ablatival
#             spr: separation
#               cnc: concrete
#               fgr: figurative
#               nna: none of the above
#               idk: I do not know
#             dst__cmp: distinction and comparison
#             cau: cause
#             fnl: purpose
#             src: source
#             nna: none of the above
#             idk: I do not know
#           tmp__plc: time and place
#             tmp: time
#               sml__lct: simultaneous location
#               squ__lct: sequential location
#               squ__drt: sequential-durative
#               tmp__dst: temporal distance
#               tmp__ext: temporal extent
#               nna: none of the above
#               idk: I do not know
#             plc: place
#               lct: location
#                 cnc: concrete
#                 fgr: figurative
#                 nna: none of the above
#                 idk: I do not know
#               drc: direction
#                 cnc: concrete
#                 fgr: figurative
#                 nna: none of the above
#                 idk: I do not know
#               pth: path
#                 cnc: concrete
#                 fgr: figurative
#                 nna: none of the above
#                 idk: I do not know
#               nna: none of the above
#               idk: I do not know
#             nna: none of the above
#             idk: I do not know
#           adp: adpositional
#             ins__mns: instrument or means
#             agt: agent
#             mnn: manner
#             frd__ass: friendly association
#             hst__ass: hostile association
#             acm: accompaniment
#             acm__crc: accompanying circumstance
#             adv: advantage
#             dsd: disadvantage
#             rfr: reference
#             cnf: conformity
#             nna: none of the above
#             idk: I do not know
#           nna: none of the above
#           idk: I do not know
#         ind: independent
#           exc: exclamation
#           nna: none of the above
#           idk: I do not know
#         nna: none of the above
#         idk: I do not know
#       dtv: dative
#         dpd: dependent
#           prp: proper
#             drc: direct complement of verbs
#             ind: indirect complement of verbs
#             int: interest
#               pss: possessor
#               adv: advantage
#               dsd: disadvantage
#               fln: feeling
#               inc__avr: with participle of inclination or aversion
#               agn: agent
#               nna: none of the above
#               idk: I do not know
#             rlt: relation
#               prp: proper
#               rfr: reference
#               exp__tmp: with a participle of expressing time
#               nna: none of the above
#               idk: I do not know
#             nna: none of the above
#             idk: I do not know
#           ins: instrumental
#             prp: proper
#               ins__mns: instrument or means
#               stn__jdg: standard of judgement
#               mnn: manner
#               msr__dff: measure of difference
#               rsp: respect
#               cau: cause
#               nna: none of the above
#               idk: I do not know
#             cmt: comitative
#               frd__ass: friendly association
#               hst__ass: hostile association
#               acm: accompaniment
#               acm__crc: accompanying circumstance
#               nna: none of the above
#               idk: I do not know
#             nna: none of the above
#             idk: I do not know
#           lcv: locative
#             plc: place
#               lct: location
#                 cnc: concrete
#                 fgr: figurative
#                 nna: none of the above
#                 idk: I do not know
#               drc: direction
#                 cnc: concrete
#                 fgr: figurative
#                 nna: none of the above
#                 idk: I do not know
#               pth: path
#                 cnc: concrete
#                 fgr: figurative
#                 nna: none of the above
#                 idk: I do not know
#               nna: none of the above
#               idk: I do not know
#             tmp: time
#               sml__lct: simultaneous location
#               squ__lct: sequential location
#               squ__drt: sequential-durative
#               tmp__dst: temporal distance
#               tmp__ext: temporal extent
#               nna: none of the above
#               idk: I do not know
#             nna: none of the above
#             idk: I do not know
#           adp: adpositional
#             fnl: purpose
#             cnf: conformity
#             prc__val: price and value
#             cnd: condition
#             nna: none of the above
#             idk: I do not know
#           nna: none of the above
#           idk: I do not know
#         nna: none of the above
#         idk: I do not know
#       acc: accusative
#         dpd: dependent
#           eff: internal object
#           aff: external object
#           ext: extent
#             spc: space
#               lct: location
#                 cnc: concrete
#                 fgr: figurative
#                 nna: none of the above
#                 idk: I do not know
#               pth: path
#                 cnc: concrete
#                 fgr: figurative
#                 nna: none of the above
#                 idk: I do not know
#               nna: none of the above
#               idk: I do not know
#             tmp: time
#               sml__lct: simultaneous location
#               squ__lct: sequential location
#               squ__drt: sequential-durative
#               tmp__dst: temporal distance
#               tmp__ext: temporal extent
#               nna: none of the above
#               idk: I do not know
#             msr: measure
#             nna: none of the above
#             idk: I do not know
#           drc: terminal
#             cnc: concrete
#             fgr: figurative
#             nna: none of the above
#             idk: I do not know
#           rsp: respect
#           adp: adpositional
#             mnn: manner
#             ins__mns: instrument or means
#             cau: cause
#             fnl: purpose
#             stn__jdg: standard of judgement
#             cmp: comparison
#             adv: advantage
#             dsd: disadvantage
#             rcp__add: recipient or addressee
#             cnf: conformity
#             frd__ass: friendly association
#             hst__ass: hostile association
#             nna: none of the above
#             idk: I do not know
#           nna: none of the above
#           idk: I do not know
#         ind: independent
#           ell: elliptical
#           nna: none of the above
#           idk: I do not know
#         nna: none of the above
#         idk: I do not know
#       vct: vocative
#       nna: none of the above
#       idk: I do not know
#     nna: none of the above
#     idk: I do not know
#   ord: ordinal
#     adj: adjective
#     sbs: substantive
#       nmn: nominative
#         dpd: dependent
#         ind: independent
#           ctc: citation
#           pnd: nominativus pendens
#           exc: exclamation
#           nna: none of the above
#           idk: I do not know
#         nna: none of the above
#         idk: I do not know
#       gnt: genitive
#         dpd: dependent
#           prp: proper
#             pss__bln: possession or belonging
#             dvd: divided whole
#             qlt: quality
#             exp: explanation
#             mtr__cnt: material or contents
#             msr: measure
#               tmp: time
#               spc: space
#               dgr: degree
#               nna: none of the above
#               idk: I do not know
#             sbj__obj: subjective or objective
#               sbj: subjective
#               obj: objective
#               nna: none of the above
#               idk: I do not know
#             prc__val: price and value
#             crm__acn: crime and accountability
#             tpc: topic
#             cnn: connection
#             nna: none of the above
#             idk: I do not know
#           abl: ablatival
#             spr: separation
#               cnc: concrete
#               fgr: figurative
#               nna: none of the above
#               idk: I do not know
#             dst__cmp: distinction and comparison
#             cau: cause
#             fnl: purpose
#             src: source
#             nna: none of the above
#             idk: I do not know
#           tmp__plc: time and place
#             tmp: time
#               sml__lct: simultaneous location
#               squ__lct: sequential location
#               squ__drt: sequential-durative
#               tmp__dst: temporal distance
#               tmp__ext: temporal extent
#               nna: none of the above
#               idk: I do not know
#             plc: place
#               lct: location
#                 cnc: concrete
#                 fgr: figurative
#                 nna: none of the above
#                 idk: I do not know
#               drc: direction
#                 cnc: concrete
#                 fgr: figurative
#                 nna: none of the above
#                 idk: I do not know
#               pth: path
#                 cnc: concrete
#                 fgr: figurative
#                 nna: none of the above
#                 idk: I do not know
#               nna: none of the above
#               idk: I do not know
#             nna: none of the above
#             idk: I do not know
#           adp: adpositional
#             ins__mns: instrument or means
#             agt: agent
#             mnn: manner
#             frd__ass: friendly association
#             hst__ass: hostile association
#             acm: accompaniment
#             acm__crc: accompanying circumstance
#             adv: advantage
#             dsd: disadvantage
#             rfr: reference
#             cnf: conformity
#             nna: none of the above
#             idk: I do not know
#           nna: none of the above
#           idk: I do not know
#         ind: independent
#           exc: exclamation
#           nna: none of the above
#           idk: I do not know
#         nna: none of the above
#         idk: I do not know
#       dtv: dative
#         dpd: dependent
#           prp: proper
#             drc: direct complement of verbs
#             ind: indirect complement of verbs
#             int: interest
#               pss: possessor
#               adv: advantage
#               dsd: disadvantage
#               fln: feeling
#               inc__avr: with participle of inclination or aversion
#               agn: agent
#               nna: none of the above
#               idk: I do not know
#             rlt: relation
#               prp: proper
#               rfr: reference
#               exp__tmp: with a participle of expressing time
#               nna: none of the above
#               idk: I do not know
#             nna: none of the above
#             idk: I do not know
#           ins: instrumental
#             prp: proper
#               ins__mns: instrument or means
#               stn__jdg: standard of judgement
#               mnn: manner
#               msr__dff: measure of difference
#               rsp: respect
#               cau: cause
#               nna: none of the above
#               idk: I do not know
#             cmt: comitative
#               frd__ass: friendly association
#               hst__ass: hostile association
#               acm: accompaniment
#               acm__crc: accompanying circumstance
#               nna: none of the above
#               idk: I do not know
#             nna: none of the above
#             idk: I do not know
#           lcv: locative
#             plc: place
#               lct: location
#                 cnc: concrete
#                 fgr: figurative
#                 nna: none of the above
#                 idk: I do not know
#               drc: direction
#                 cnc: concrete
#                 fgr: figurative
#                 nna: none of the above
#                 idk: I do not know
#               pth: path
#                 cnc: concrete
#                 fgr: figurative
#                 nna: none of the above
#                 idk: I do not know
#               nna: none of the above
#               idk: I do not know
#             tmp: time
#               sml__lct: simultaneous location
#               squ__lct: sequential location
#               squ__drt: sequential-durative
#               tmp__dst: temporal distance
#               tmp__ext: temporal extent
#               nna: none of the above
#               idk: I do not know
#             nna: none of the above
#             idk: I do not know
#           adp: adpositional
#             fnl: purpose
#             cnf: conformity
#             prc__val: price and value
#             cnd: condition
#             nna: none of the above
#             idk: I do not know
#           nna: none of the above
#           idk: I do not know
#         nna: none of the above
#         idk: I do not know
#       acc: accusative
#         dpd: dependent
#           eff: internal object
#           aff: external object
#           ext: extent
#             spc: space
#               lct: location
#                 cnc: concrete
#                 fgr: figurative
#                 nna: none of the above
#                 idk: I do not know
#               pth: path
#                 cnc: concrete
#                 fgr: figurative
#                 nna: none of the above
#                 idk: I do not know
#               nna: none of the above
#               idk: I do not know
#             tmp: time
#               sml__lct: simultaneous location
#               squ__lct: sequential location
#               squ__drt: sequential-durative
#               tmp__dst: temporal distance
#               tmp__ext: temporal extent
#               nna: none of the above
#               idk: I do not know
#             msr: measure
#             nna: none of the above
#             idk: I do not know
#           drc: terminal
#             cnc: concrete
#             fgr: figurative
#             nna: none of the above
#             idk: I do not know
#           rsp: respect
#           adp: adpositional
#             mnn: manner
#             ins__mns: instrument or means
#             cau: cause
#             fnl: purpose
#             stn__jdg: standard of judgement
#             cmp: comparison
#             adv: advantage
#             dsd: disadvantage
#             rcp__add: recipient or addressee
#             cnf: conformity
#             frd__ass: friendly association
#             hst__ass: hostile association
#             nna: none of the above
#             idk: I do not know
#           nna: none of the above
#           idk: I do not know
#         ind: independent
#           ell: elliptical
#           nna: none of the above
#           idk: I do not know
#         nna: none of the above
#         idk: I do not know
#       vct: vocative
#       nna: none of the above
#       idk: I do not know
#     nna: none of the above
#     idk: I do not know
#   adv: adverb
#     tmp: time
#       sml__lct: simultaneous location
#       squ__lct: sequential location
#       squ__drt: sequential-durative
#       tmp__dst: temporal distance
#       tmp__ext: temporal extent
#       nna: none of the above
#       idk: I do not know
#     plc: place
#       lct: location
#         cnc: concrete
#         fgr: figurative
#         nna: none of the above
#         idk: I do not know
#       drc: direction
#         cnc: concrete
#         fgr: figurative
#         nna: none of the above
#         idk: I do not know
#       pth: path
#         cnc: concrete
#         fgr: figurative
#         nna: none of the above
#         idk: I do not know
#       spr: separation
#         cnc: concrete
#         fgr: figurative
#         nna: none of the above
#         idk: I do not know
#       nna: none of the above
#       idk: I do not know
#     src: source
#     cau: cause
#     cns: result
#     mnn: manner
#     msr: measure
#     ins__mns: instrument or means
#     fnl: purpose
#     cnc: concession
#     ngt: negation
#     prt: particle
#     nna: none of the above
#     idk: I do not know
#   nna: none of the above
#   idk: I do not know
