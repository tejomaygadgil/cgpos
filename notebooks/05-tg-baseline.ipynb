# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import logging
from collections import defaultdict, Counter
import random
import copy

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from hydra import initialize, compose
import hydra
from greek_accentuation.characters import strip_accents, strip_breathing
from nltk import edit_distance

from cgpos.utils.util import import_pkl, export_pkl

# %%
# Reset hydra
hydra.core.global_hydra.GlobalHydra.instance().clear()
# Load hydra params
initialize("../conf/", version_base=None)
config = compose(config_name='main')
# Init logger
logging.basicConfig(level=logging.INFO)

# %%
# Load data
data = import_pkl(config.perseus.featurized)
# Out:
# INFO:cgpos.utils.util:Importing /home/tejomay/cgpos/data/processed/perseus_featurized.pkl

# %%
# Bag of syllables
def bos(data, train=0.8, verbose=True, seed=20):
    logger = logging.getLogger(__name__)

    # Drop data missing part-of-speech 
    data = [word for word in data if 'pos' in word]
    
    # Train test split
    random.seed(seed)
    shuffled = random.sample(data, len(data))
    train_ind = int(len(data) * train)
    train_data = shuffled[:train_ind] 
    test_data = shuffled[train_ind:]

    if verbose:
        logger.info(f"Train-test split {train}: (train={len(train_data)}, test={len(test_data)}) [seed={seed}]")

    # Train
    bos = defaultdict(Counter)
    for word in train_data:
        if 'pos' in word:
            pos = word['pos']
            for syllable in word['syllables']:
                bos[syllable][pos] +=1

    # Test
    unseen_syllables = []
    word_data = []
    for word in test_data:
        uid = word['uid']
        form = word['form']
        norm = word['norm']
        syllables = word['syllables']
        true_pos = word['pos']
        syllable_data = []
        syllable_preds = []
        has_unseen = False
        for syllable in syllables:
            if (syllable in bos):
                syllable_bos = bos[syllable]
                syllable_pred = max(syllable_bos, key=syllable_bos.get)    
                syllable_data.append((syllable, syllable_bos))
                syllable_preds.append(syllable_pred)
            else:
                has_unseen = True                
                unseen_syllables.append({
                    'uid': uid, 
                    'form': form, 
                    'norm': norm, 
                    'pos': pos, 
                    'syllable': syllable, 
                    'syllables': syllables,
                })
        pred_pos = None
        if syllable_preds:
            pred_pos = max(set(syllable_preds), key=syllable_preds.count)
        word_data.append({
            'has_unseen_syllable': has_unseen,
            'uid': uid,
            'form': form,
            'norm': norm,
            'sylables': syllables,
            'true_pos': true_pos,
            'pred_pos': pred_pos,
            'syllable_preds': syllable_preds,
            'syllable_data': syllable_data,
        })
    
    accuracy = sum([(word['true_pos'] == word['pred_pos']) for word in word_data]) / len(word_data)
    
    if verbose:
        len_unseen_syllables = len(unseen_syllables)
        percent_unseen_syllables = len_unseen_syllables / sum([len(word['syllables']) for word in test_data])
        logger.info(f"Accuracy: {accuracy * 100:.2f}%, unseen syllables: {len_unseen_syllables} ({percent_unseen_syllables * 100:.2f}% missing)")

    results = {
        'train_data': train_data,
        'test_data': test_data,
        'word_data': word_data,
        'bos': bos,
        'unseen_syllables': unseen_syllables,
        'accuracy': accuracy,
        'seed': seed,
    }

    return results

def cv(data, model=bos, folds=10, **kwargs):
    logger = logging.getLogger(__name__)
    logger.info(f"Running {folds}-fold CV on Bag-of-Syllables model:")
    results = []
    accuracies = []
    for i in range(1, folds + 1):
        logger.info(f"Training fold {i}:")
        seed = random.randint(1, 2**10)
        result = model(data, seed=seed, **kwargs)
        accuracy = result['accuracy']
        results.append(result)
        accuracies.append(accuracy)
    logger.info(f"Final {folds}-fold CV accuracy: accuracy {np.mean(accuracies) * 100:.2f}%, std {np.std(accuracies):.2f}")
    return results

# %%
results = cv(data)
# Out:
# INFO:__main__:Running 10-fold CV on Bag-of-Syllables model:
# INFO:__main__:Training fold 1:
# INFO:__main__:Train-test split 0.8: (train=439916, test=109980) [seed=345]
# INFO:__main__:Accuracy: 69.01%, unseen syllables: 466 (0.21% missing)
# INFO:__main__:Training fold 2:
# INFO:__main__:Train-test split 0.8: (train=439916, test=109980) [seed=94]
# INFO:__main__:Accuracy: 68.96%, unseen syllables: 488 (0.22% missing)
# INFO:__main__:Training fold 3:
# INFO:__main__:Train-test split 0.8: (train=439916, test=109980) [seed=517]
# INFO:__main__:Accuracy: 69.00%, unseen syllables: 478 (0.21% missing)
# INFO:__main__:Training fold 4:
# INFO:__main__:Train-test split 0.8: (train=439916, test=109980) [seed=18]
# INFO:__main__:Accuracy: 68.90%, unseen syllables: 498 (0.22% missing)
# INFO:__main__:Training fold 5:
# INFO:__main__:Train-test split 0.8: (train=439916, test=109980) [seed=86]
# INFO:__main__:Accuracy: 68.68%, unseen syllables: 452 (0.20% missing)
# INFO:__main__:Training fold 6:
# INFO:__main__:Train-test split 0.8: (train=439916, test=109980) [seed=31]
# INFO:__main__:Accuracy: 68.59%, unseen syllables: 510 (0.22% missing)
# INFO:__main__:Training fold 7:
# INFO:__main__:Train-test split 0.8: (train=439916, test=109980) [seed=702]
# INFO:__main__:Accuracy: 69.07%, unseen syllables: 479 (0.21% missing)
# INFO:__main__:Training fold 8:
# INFO:__main__:Train-test split 0.8: (train=439916, test=109980) [seed=409]
# INFO:__main__:Accuracy: 68.72%, unseen syllables: 483 (0.21% missing)
# INFO:__main__:Training fold 9:
# INFO:__main__:Train-test split 0.8: (train=439916, test=109980) [seed=178]
# INFO:__main__:Accuracy: 68.71%, unseen syllables: 480 (0.21% missing)
# INFO:__main__:Training fold 10:
# INFO:__main__:Train-test split 0.8: (train=439916, test=109980) [seed=955]
# INFO:__main__:Accuracy: 69.02%, unseen syllables: 499 (0.22% missing)
# INFO:__main__:Final 10-fold CV accuracy: accuracy 68.87%, std 0.00

# %%
results[0]['word_data'][:10]
# Out:
# [{'has_unseen_syllable': False,
#   'uid': '76364',
#   'form': 'τέ',
#   'norm': 'τέ',
#   'sylables': ['τέ'],
#   'true_pos': 'particle',
#   'pred_pos': 'verb',
#   'syllable_preds': ['verb'],
#   'syllable_data': [('τέ',
#     Counter({'verb': 920,
#              'adjective': 799,
#              'noun': 726,
#              'particle': 163,
#              'adverb': 158,
#              'pronoun': 15,
#              'conjunction': 4,
#              'irregular': 1,
#              'N/A': 1}))]},
#  {'has_unseen_syllable': False,
#   'uid': '374327',
#   'form': 'εἴ',
#   'norm': 'εἴ',
#   'sylables': ['εἴ'],
#   'true_pos': 'conjunction',
#   'pred_pos': 'verb',
#   'syllable_preds': ['verb'],
#   'syllable_data': [('εἴ',
#     Counter({'verb': 613,
#              'conjunction': 427,
#              'adverb': 60,
#              'noun': 56,
#              'adjective': 52,
#              'adposition': 32,
#              'numeral': 19,
#              'interjection': 5,
#              'N/A': 2}))]},
#  {'has_unseen_syllable': False,
#   'uid': '240086',
#   'form': 'φησι',
#   'norm': 'φησι',
#   'sylables': ['φη', 'σι'],
#   'true_pos': 'verb',
#   'pred_pos': 'verb',
#   'syllable_preds': ['verb', 'noun'],
#   'syllable_data': [('φη',
#     Counter({'verb': 823, 'noun': 59, 'adjective': 22, 'adverb': 3})),
#    ('σι',
#     Counter({'noun': 2662,
#              'verb': 1591,
#              'adjective': 1547,
#              'pronoun': 272,
#              'article': 124,
#              'adverb': 34,
#              'numeral': 27,
#              'N/A': 2,
#              'irregular': 2}))]},
#  {'has_unseen_syllable': False,
#   'uid': '554151',
#   'form': 'Ἀλκιβιάδου',
#   'norm': 'Ἀλκιβιάδου',
#   'sylables': ['Ἀλ', 'κι', 'βι', 'ά', 'δου'],
#   'true_pos': 'noun',
#   'pred_pos': 'noun',
#   'syllable_preds': ['noun', 'noun', 'noun', 'noun', 'noun'],
#   'syllable_data': [('Ἀλ', Counter({'noun': 225, 'conjunction': 4, 'N/A': 1})),
#    ('κι',
#     Counter({'noun': 361,
#              'adjective': 291,
#              'verb': 230,
#              'adverb': 32,
#              'N/A': 5})),
#    ('βι', Counter({'noun': 223, 'verb': 111, 'adjective': 65, 'adverb': 7})),
#    ('ά',
#     Counter({'noun': 934,
#              'verb': 397,
#              'adjective': 209,
#              'adposition': 29,
#              'pronoun': 19,
#              'N/A': 13,
#              'adverb': 10,
#              'numeral': 4,
#              'interjection': 2})),
#    ('δου', Counter({'noun': 298, 'verb': 106, 'adjective': 44, 'N/A': 1}))]},
#  {'has_unseen_syllable': False,
#   'uid': '138514',
#   'form': ',',
#   'norm': ',',
#   'sylables': [','],
#   'true_pos': 'punctuation',
#   'pred_pos': 'punctuation',
#   'syllable_preds': ['punctuation'],
#   'syllable_data': [(',', Counter({'punctuation': 28883}))]},
#  {'has_unseen_syllable': False,
#   'uid': '43793',
#   'form': 'ἀληθῶς',
#   'norm': 'ἀληθῶς',
#   'sylables': ['ἀ', 'λη', 'θῶς'],
#   'true_pos': 'adverb',
#   'pred_pos': 'verb',
#   'syllable_preds': ['verb', 'noun', 'adverb'],
#   'syllable_data': [('ἀ',
#     Counter({'verb': 5656,
#              'adjective': 2893,
#              'noun': 2737,
#              'adposition': 703,
#              'adverb': 503,
#              'particle': 111,
#              'N/A': 18,
#              'pronoun': 13,
#              'conjunction': 6})),
#    ('λη',
#     Counter({'noun': 465,
#              'verb': 295,
#              'adjective': 281,
#              'adverb': 18,
#              'N/A': 7,
#              'pronoun': 3})),
#    ('θῶς', Counter({'adverb': 50}))]},
#  {'has_unseen_syllable': False,
#   'uid': '52806',
#   'form': 'νώνυμος',
#   'norm': 'νώνυμος',
#   'sylables': ['νώ', 'νυ', 'μος'],
#   'true_pos': 'adjective',
#   'pred_pos': 'noun',
#   'syllable_preds': ['verb', 'noun', 'noun'],
#   'syllable_data': [('νώ',
#     Counter({'verb': 126, 'adjective': 44, 'noun': 36, 'adverb': 1})),
#    ('νυ',
#     Counter({'noun': 202,
#              'verb': 139,
#              'adjective': 133,
#              'adverb': 90,
#              'N/A': 3})),
#    ('μος',
#     Counter({'noun': 248,
#              'adjective': 230,
#              'adverb': 32,
#              'conjunction': 16,
#              'N/A': 1}))]},
#  {'has_unseen_syllable': False,
#   'uid': '193781',
#   'form': 'θάλατταν',
#   'norm': 'θάλατταν',
#   'sylables': ['θά', 'λατ', 'ταν'],
#   'true_pos': 'noun',
#   'pred_pos': 'noun',
#   'syllable_preds': ['noun', 'noun', 'conjunction'],
#   'syllable_data': [('θά',
#     Counter({'noun': 343,
#              'verb': 145,
#              'adverb': 110,
#              'adjective': 82,
#              'conjunction': 25})),
#    ('λατ', Counter({'noun': 40, 'verb': 26, 'adjective': 7})),
#    ('ταν',
#     Counter({'conjunction': 98,
#              'noun': 92,
#              'adjective': 11,
#              'adverb': 9,
#              'adposition': 3,
#              'verb': 3}))]},
#  {'has_unseen_syllable': False,
#   'uid': '46389',
#   'form': 'αὐδά',
#   'norm': 'αὐδά',
#   'sylables': ['αὐ', 'δά'],
#   'true_pos': 'noun',
#   'pred_pos': 'pronoun',
#   'syllable_preds': ['pronoun', 'noun'],
#   'syllable_data': [('αὐ',
#     Counter({'pronoun': 1926,
#              'adjective': 1684,
#              'particle': 578,
#              'adverb': 357,
#              'noun': 265,
#              'conjunction': 72,
#              'verb': 60,
#              'N/A': 4})),
#    ('δά',
#     Counter({'noun': 337,
#              'verb': 177,
#              'adjective': 112,
#              'adverb': 2,
#              'N/A': 1}))]},
#  {'has_unseen_syllable': False,
#   'uid': '374215',
#   'form': ',',
#   'norm': ',',
#   'sylables': [','],
#   'true_pos': 'punctuation',
#   'pred_pos': 'punctuation',
#   'syllable_preds': ['punctuation'],
#   'syllable_data': [(',', Counter({'punctuation': 28883}))]}]

# %%
# Export results
export_pkl(results, config.results.bos)
# Out:
# INFO:cgpos.utils.util:Exporting /home/tejomay/cgpos/data/results/bos.pkl

# %%
# Try removing accents
data_no_accent = copy.deepcopy(data)
for word in data_no_accent:
    if 'syllables' in word:
        word['syllables'] = [strip_breathing(strip_accents(syllable)) for syllable in word['syllables']]

# %%
[word['syllables'] for word in data][:10]
# Out:
# [['Θου', 'κυ', 'δί', 'δης'],
#  ['Ἀ', 'θη', 'ναῖ', 'ος'],
#  ['ξυ', 'νέ', 'γρα', 'ψε'],
#  ['τὸν'],
#  ['πό', 'λε', 'μον'],
#  ['τῶν'],
#  ['Πε', 'λο', 'πον', 'νη', 'σί', 'ων'],
#  ['καὶ'],
#  ['Ἀ', 'θη', 'ναί', 'ων'],
#  [',']]

# %%
[word['syllables'] for word in data_no_accent][:10]
# Out:
# [['Θου', 'κυ', 'δι', 'δης'],
#  ['Α', 'θη', 'ναι', 'ος'],
#  ['ξυ', 'νε', 'γρα', 'ψε'],
#  ['τον'],
#  ['πο', 'λε', 'μον'],
#  ['των'],
#  ['Πε', 'λο', 'πον', 'νη', 'σι', 'ων'],
#  ['και'],
#  ['Α', 'θη', 'ναι', 'ων'],
#  [',']]

# %%
_ = cv(data_no_accent)
# Out:
# INFO:__main__:Running 10-fold CV on Bag-of-Syllables model:
# INFO:__main__:Training fold 1:
# INFO:__main__:Train-test split 0.8: (train=439916, test=109980) [seed=555]
# INFO:__main__:Accuracy: 61.54%, unseen syllables: 225 (0.10% missing)
# INFO:__main__:Training fold 2:
# INFO:__main__:Train-test split 0.8: (train=439916, test=109980) [seed=388]
# INFO:__main__:Accuracy: 61.78%, unseen syllables: 180 (0.08% missing)
# INFO:__main__:Training fold 3:
# INFO:__main__:Train-test split 0.8: (train=439916, test=109980) [seed=258]
# INFO:__main__:Accuracy: 61.62%, unseen syllables: 214 (0.09% missing)
# INFO:__main__:Training fold 4:
# INFO:__main__:Train-test split 0.8: (train=439916, test=109980) [seed=451]
# INFO:__main__:Accuracy: 61.58%, unseen syllables: 192 (0.08% missing)
# INFO:__main__:Training fold 5:
# INFO:__main__:Train-test split 0.8: (train=439916, test=109980) [seed=661]
# INFO:__main__:Accuracy: 61.40%, unseen syllables: 198 (0.09% missing)
# INFO:__main__:Training fold 6:
# INFO:__main__:Train-test split 0.8: (train=439916, test=109980) [seed=31]
# INFO:__main__:Accuracy: 61.28%, unseen syllables: 222 (0.10% missing)
# INFO:__main__:Training fold 7:
# INFO:__main__:Train-test split 0.8: (train=439916, test=109980) [seed=702]
# INFO:__main__:Accuracy: 61.76%, unseen syllables: 198 (0.09% missing)
# INFO:__main__:Training fold 8:
# INFO:__main__:Train-test split 0.8: (train=439916, test=109980) [seed=409]
# INFO:__main__:Accuracy: 61.33%, unseen syllables: 220 (0.10% missing)
# INFO:__main__:Training fold 9:
# INFO:__main__:Train-test split 0.8: (train=439916, test=109980) [seed=178]
# INFO:__main__:Accuracy: 61.53%, unseen syllables: 225 (0.10% missing)
# INFO:__main__:Training fold 10:
# INFO:__main__:Train-test split 0.8: (train=439916, test=109980) [seed=955]
# INFO:__main__:Accuracy: 61.73%, unseen syllables: 198 (0.09% missing)
# INFO:__main__:Final 10-fold CV accuracy: accuracy 61.56%, std 0.00
