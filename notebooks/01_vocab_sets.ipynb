# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import src.config as cfg
from src.util import read_pkl

# %%
"ὰ" in " ".join(pt_text)
# Out:
# False

# %%
ft_syl = read_pkl(cfg.ft_syl)
pt_syl = read_pkl(cfg.pt_syl)
vft = set(ft_syl)
vpt = set(pt_syl)

# %%
len(vpt)
# Out:
# 17015

# %%
len(vft)
# Out:
# 8099

# %%
len(vft - vpt)
# Out:
# 25

# %%
ft_syl[:1000]
# Out:
# ['Θου',
#  'κυ',
#  'δί',
#  'δης',
#  ' ',
#  'Ἀ',
#  'θη',
#  'ναῖ',
#  'ος',
#  ' ',
#  'ξυ',
#  'νέ',
#  'γρα',
#  'ψε',
#  ' ',
#  'τὸν',
#  ' ',
#  'πό',
#  'λε',
#  'μον',
#  ' ',
#  'τῶν',
#  ' ',
#  'Πε',
#  'λο',
#  'πον',
#  'νη',
#  'σί',
#  'ων',
#  ' ',
#  'καὶ',
#  ' ',
#  'Ἀ',
#  'θη',
#  'ναί',
#  'ων',
#  ' ',
#  ',',
#  ' ',
#  'ὡς',
#  ' ',
#  'ἐ',
#  'πο',
#  'λέ',
#  'μη',
#  'σαν',
#  ' ',
#  'πρὸς',
#  ' ',
#  'ἀλ',
#  'λή',
#  'λους',
#  ' ',
#  ',',
#  ' ',
#  'ἀρ',
#  'ξά',
#  'με',
#  'νος',
#  ' ',
#  'εὐ',
#  'θὺς',
#  ' ',
#  'κα',
#  'θι',
#  'στα',
#  'μέ',
#  'νου',
#  ' ',
#  'καὶ',
#  ' ',
#  'ἐλ',
#  'πί',
#  'σας',
#  ' ',
#  'μέ',
#  'γαν',
#  ' ',
#  'τε',
#  ' ',
#  'ἔ',
#  'σε',
#  'σθαι',
#  ' ',
#  'καὶ',
#  ' ',
#  'ἀ',
#  'ξι',
#  'ο',
#  'λο',
#  'γώ',
#  'τα',
#  'τον',
#  ' ',
#  'τῶν',
#  ' ',
#  'προ',
#  'γε',
#  'γε',
#  'νη',
#  'μέ',
#  'νων',
#  ' ',
#  ',',
#  ' ',
#  'τεκ',
#  'μαι',
#  'ρό',
#  'με',
#  'νος',
#  ' ',
# ...

# %%
len(vpt - vft)
# Out:
# 8941

# %%
len(vpt.union(vft))
# Out:
# 17040

# %%
list(vft - vpt)[:1000]
# Out:
# ['χισθ',
#  'αις',
#  'δρὼν',
#  'τῴ',
#  'κροὺς',
#  'πτυχ',
#  'νεῦν',
#  'πραχ',
#  'πτρῳ',
#  'στᾳ',
#  'μήθ',
#  'ναῖς',
#  'τοσθ',
#  'ξυσ',
#  'Μιν',
#  'πάνθ',
#  'λυφθ',
#  'φοιτ',
#  'κτην',
#  'ῥεί',
#  'Γᾶν',
#  'ΐν',
#  'ς',
#  'τοῦς',
#  'οιγ',
#  'ράι',
#  'κόνθ',
#  'Κτε',
#  'παγλ',
#  'ὴν',
#  'Γᾶ',
#  'σχρον',
#  'ζὼν',
#  'τἄρ',
#  'πήχ',
#  'θοῦθ',
#  'σθῶ',
#  'σουσ',
#  'ψὼ',
#  'σχεις',
#  'ὔμ',
#  'ἵν',
#  'φεὶς',
#  'πτιν',
#  'λεῖθ',
#  'θνᾴ',
#  'κρῷ',
#  'δὺν',
#  'λείμ',
#  'πνει',
#  'πωπ',
#  'κοιν',
#  'ζεις',
#  'πλαῖς',
#  'βροί',
#  'σφοις',
#  'θαχ',
#  'ἧντ',
#  'τεὶς',
#  'ὧν',
#  'λεῖπ',
#  'δ̓',
#  'πρήσ',
#  'κοὺς',
#  'σχρῶν',
#  'στοις',
#  'σκετ',
#  'ἂρ',
#  'ὗν',
#  'μες',
#  'λόντ',
#  'πᾷ',
#  'πριγδ',
#  'φὶ',
#  'γὶς',
#  'ἠύτ',
#  'λάδ',
#  'κοις',
#  'ζεῦξ',
#  'ρᾷ',
#  'μνέρ',
#  'θρεψ',
#  'πτειν',
#  'μῖν',
#  'στούν',
#  'μνάν',
#  'βαλλ',
#  'αὖθ',
#  'δρην',
#  'Ζάρ',
#  'οῖν',
#  'δάχ',
#  'σχρὰν',
#  'χεῖς',
#  'θρίπ',
# ...
