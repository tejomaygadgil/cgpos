# %%
import os

# %%
DATA_DIR = '../data/raw/canonical-greekLit-master'
file_name = os.listdir(DATA_DIR)

# %%
file_name
# Out:
# ['pre-install.xql',
#  'manifest.txt',
#  'expath-pkg.xml',
#  'build.xml',
#  '.gitignore',
#  'repo.xml',
#  'collection.xconf',
#  'canonical-greekLit.tracking.json',
#  '.github',
#  'data',
#  'README.md',
#  'license.md']

# %%
path = os.path.join(DATA_DIR, file_name)

with open(path) as f:
    files = f.readlines()

# %%
files
# Out:
# ['/data/tlg0001/__cts__.xml\n',
#  '/data/tlg0001/tlg001/__cts__.xml\n',
#  '/data/tlg0001/tlg001/tlg0001.tlg001.perseus-grc2.xml\n',
#  '/data/tlg0003/__cts__.xml\n',
#  '/data/tlg0003/tlg001/__cts__.xml\n',
#  '/data/tlg0003/tlg001/tlg0003.tlg001.opp-fre1.xml\n',
#  '/data/tlg0003/tlg001/tlg0003.tlg001.opp-ger1.xml\n',
#  '/data/tlg0003/tlg001/tlg0003.tlg001.opp-ger2.xml\n',
#  '/data/tlg0003/tlg001/tlg0003.tlg001.perseus-eng4.xml\n',
#  '/data/tlg0003/tlg001/tlg0003.tlg001.perseus-eng6.xml\n',
#  '/data/tlg0003/tlg001/tlg0003.tlg001.perseus-grc2.xml\n',
#  '/data/tlg0004/__cts__.xml\n',
#  '/data/tlg0004/tlg001/__cts__.xml\n',
#  '/data/tlg0004/tlg001/tlg0004.tlg001.perseus-eng2.xml\n',
#  '/data/tlg0004/tlg001/tlg0004.tlg001.perseus-grc2.xml\n',
#  '/data/tlg0005/__cts__.xml\n',
#  '/data/tlg0005/tlg001/__cts__.xml\n',
#  '/data/tlg0005/tlg001/tlg0005.tlg001.perseus-grc2.xml\n',
#  '/data/tlg0005/tlg002/__cts__.xml\n',
#  '/data/tlg0005/tlg002/tlg0005.tlg002.perseus-grc2.xml\n',
# ...
